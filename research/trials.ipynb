# %% [markdown]
# # configbox

# %%
import yaml

yaml_file_path="test.yaml"
# Open the YAML file and load its contents
with open(yaml_file_path, 'r') as yaml_file:
    data = yaml.safe_load(yaml_file)
print(data)
# Out:
# {'name': 'himanth'}

# %%
data["name"]
# Out:
# 'himanth'

# %%
data["Email"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 data["Email"]
#
# KeyError: 'Email'

# %%
from box import ConfigBox

config_data = ConfigBox(data)

config_data.name
# Out:
# 'himanth'

# %% [markdown]
# ensure_annotations

# %%
def get_product(x:int, y:int):
    return x*y

# %%
get_product(x=2,y=4)
# Out:
# 8

# %%
get_product(x=2,y="4")
# Out:
# '44'

# %%
from ensure import ensure_annotations

# %%
@ensure_annotations
def get_product(x:int, y:int):
    return x*y

# %%
get_product(x=2,y=4)
# Out:
# 8

# %%
get_product(x=2,y="4")
# Out:
# ---------------------------------------------------------------------------
# EnsureError                               Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 get_product(x=2,y="4")
#
# File c:\Users\ADMIN\anaconda3\envs\chest\lib\site-packages\ensure\main.py:803, in WrappedFunction.__call__(self, *args, **kwargs)
#     798     if not isinstance(value, templ):
#     799         msg = (
#     800             "Argument {arg} of type {valt} to {f} "
#     801             "does not match annotation type {t}"
#     802         )
# --> 803         raise EnsureError(msg.format(
#     804             arg=arg, f=self.f, t=templ, valt=type(value)
#     805         ))
#     807 return self.f(*args, **kwargs)
#
# EnsureError: Argument y of type <class 'str'> to <function get_product at 0x0000024CD3534F70> does not match annotation type <class 'int'>

# %% [markdown]
# Download data from gdrive

# %%
import gdown
